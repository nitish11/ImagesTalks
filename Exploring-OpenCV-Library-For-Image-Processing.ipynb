# %% [markdown]
# # Basic Operations on Images

# %% [markdown]
# What are images?

# %%
from IPython.display import Image

# %% [markdown]
# This is what we humans percieve as an image

# %%
Image(filename='resources/lincon-image.png')

# %% [markdown]
# This is what an image for computers and machines, it is just an array of pixels

# %%
Image(filename='resources/lincon.png', width=900, height=600)

# %% [markdown]
# ## Accessing images using OpenCV

# %%
import cv2 # <- opencv library import
import matplotlib.pyplot as plt
# %matplotlib inline
